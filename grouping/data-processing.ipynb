# %% [markdown]
# https://observablehq.com/@d3/tree
#
# ```javascript
# family = d3.hierarchy({
#   name: "root",
#   children: [
#     {name: "child #1"},
#     {
#       name: "child #2",
#       children: [
#         {name: "grandchild #1"},
#         {name: "grandchild #2"},
#         {name: "grandchild #3"}
#       ]
#     }
#   ]
# })
# ```

# %%
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from rich import print

# %%
csv_df = pd.read_csv('./2023기본연구열원분류.csv')
csv_df
# Out:
#          이름    종류   요소 대상량 흐름(냉방:out, 난방:in, 요소기준)
# 0        호텔    건물   공기   열                   inout
# 1        호텔    건물    물   열                      in
# 2        호텔    건물   기기  전기                      in
# 3     테이터센터    건물   공기   열                     out
# 4     테이터센터    건물   기기  전기                      in
# 5     테이터센터    건물   기기  전기                      in
# 6       태양열  에너지원   태양   열                     out
# 7       태양광  에너지원  배터리  전기                     out
# 8        지열  에너지원   토양   열                   inout
# 9       오피스    건물   공기   열                     out
# 10      오피스    건물    물   열                      in
# 11      오피스    건물   기기  전기                      in
# 12      아파트    건물   공기   열                   inout
# 13      아파트    건물    물   열                      in
# 14      아파트    건물   기기  전기                      in
# 15      수영장    건물    물   열                      in
# 16      수영장    건물   공기   열                   inout
# 17      수영장    건물   기기  전기                      in
# 18      쇼핑몰    건물   공기   열                   inout
# 19      쇼핑몰    건물    물   열                      in
# 20      쇼핑몰    건물   기기  전기                      in
# 21      목욕탕    건물   공기   열                   inout
# 22      목욕탕    건물    물   열                      in
# 23      목욕탕    건물   기기  전기                      in
# 24     냉동창고    건물   공기   열                     out
# 25     냉동창고    건물   기기  전기                      in
# 26      기지국    건물   공기   열                     out
# 27      기지국    건물   기기  전기                      in
# 28      공기열  에너지원   공기   열                   inout
# 29  ESS 격납고    건물  배터리  전기                   inout
# 30  ESS 격납고    건물   공기   열                     out
# 31  ESS 격납고    건물   기기  전기                      in
# 32      발전소  에너지원   기기  전기                     out
# 33      발전소  에너지원   기기   열                     out
# 34       학교    건물   공기   열                   inout
# 35       학교    건물   기기  전기                      in
# 36       학교    건물    물   열                      in
# 37      경기장    건물   공기   열                     out
# 38      경기장    건물   기기  전기                      in
# 39       병원    건물   기기  전기                      in
# 40       공장    건물   공기   열                     out

# %%
csv_df.rename(columns={"흐름(냉방:out, 난방:in, 요소기준)": '흐름'}, inplace=True)

# %% [markdown]
# inout 변경

# %%
_df = csv_df[csv_df["흐름"] == "inout"].copy()

_df_in = _df.copy()
_df_in["흐름"] = 'in'

_df_out = _df.copy()
_df_out["흐름"] = 'out'

_df = csv_df[csv_df["흐름"] != "inout"].copy()

csv_df = pd.concat([_df, _df_in, _df_out])
csv_df
# Out:
#          이름    종류   요소 대상량   흐름
# 1        호텔    건물    물   열   in
# 2        호텔    건물   기기  전기   in
# 3     테이터센터    건물   공기   열  out
# 4     테이터센터    건물   기기  전기   in
# 5     테이터센터    건물   기기  전기   in
# 6       태양열  에너지원   태양   열  out
# 7       태양광  에너지원  배터리  전기  out
# 9       오피스    건물   공기   열  out
# 10      오피스    건물    물   열   in
# 11      오피스    건물   기기  전기   in
# 13      아파트    건물    물   열   in
# 14      아파트    건물   기기  전기   in
# 15      수영장    건물    물   열   in
# 17      수영장    건물   기기  전기   in
# 19      쇼핑몰    건물    물   열   in
# 20      쇼핑몰    건물   기기  전기   in
# 22      목욕탕    건물    물   열   in
# 23      목욕탕    건물   기기  전기   in
# 24     냉동창고    건물   공기   열  out
# 25     냉동창고    건물   기기  전기   in
# 26      기지국    건물   공기   열  out
# 27      기지국    건물   기기  전기   in
# 30  ESS 격납고    건물   공기   열  out
# 31  ESS 격납고    건물   기기  전기   in
# 32      발전소  에너지원   기기  전기  out
# 33      발전소  에너지원   기기   열  out
# 35       학교    건물   기기  전기   in
# 36       학교    건물    물   열   in
# 37      경기장    건물   공기   열  out
# 38      경기장    건물   기기  전기   in
# 39       병원    건물   기기  전기   in
# 40       공장    건물   공기   열  out
# 0        호텔    건물   공기   열   in
# 8        지열  에너지원   토양   열   in
# 12      아파트    건물   공기   열   in
# 16      수영장    건물   공기   열   in
# 18      쇼핑몰    건물   공기   열   in
# 21      목욕탕    건물   공기   열   in
# 28      공기열  에너지원   공기   열   in
# 29  ESS 격납고    건물  배터리  전기   in
# 34       학교    건물   공기   열   in
# 0        호텔    건물   공기   열  out
# 8        지열  에너지원   토양   열  out
# 12      아파트    건물   공기   열  out
# 16      수영장    건물   공기   열  out
# 18      쇼핑몰    건물   공기   열  out
# 21      목욕탕    건물   공기   열  out
# 28      공기열  에너지원   공기   열  out
# 29  ESS 격납고    건물  배터리  전기  out
# 34       학교    건물   공기   열  out

# %%
df = csv_df[csv_df['대상량'] != "전기"]
df
# Out:
#          이름    종류  요소 대상량   흐름
# 1        호텔    건물   물   열   in
# 3     테이터센터    건물  공기   열  out
# 6       태양열  에너지원  태양   열  out
# 9       오피스    건물  공기   열  out
# 10      오피스    건물   물   열   in
# 13      아파트    건물   물   열   in
# 15      수영장    건물   물   열   in
# 19      쇼핑몰    건물   물   열   in
# 22      목욕탕    건물   물   열   in
# 24     냉동창고    건물  공기   열  out
# 26      기지국    건물  공기   열  out
# 30  ESS 격납고    건물  공기   열  out
# 33      발전소  에너지원  기기   열  out
# 36       학교    건물   물   열   in
# 37      경기장    건물  공기   열  out
# 40       공장    건물  공기   열  out
# 0        호텔    건물  공기   열   in
# 8        지열  에너지원  토양   열   in
# 12      아파트    건물  공기   열   in
# 16      수영장    건물  공기   열   in
# 18      쇼핑몰    건물  공기   열   in
# 21      목욕탕    건물  공기   열   in
# 28      공기열  에너지원  공기   열   in
# 34       학교    건물  공기   열   in
# 0        호텔    건물  공기   열  out
# 8        지열  에너지원  토양   열  out
# 12      아파트    건물  공기   열  out
# 16      수영장    건물  공기   열  out
# 18      쇼핑몰    건물  공기   열  out
# 21      목욕탕    건물  공기   열  out
# 28      공기열  에너지원  공기   열  out
# 34       학교    건물  공기   열  out

# %% [markdown]
# 이건 나중에 바꿀 수 있음

# %%
# df = df.reset_index().set_index(['종류', '대상량', '흐름', '요소', '이름']).sort_index()
df = df.reset_index().set_index(['흐름', '종류', '요소', '이름']).sort_index()
df
# Out:
#                      index 대상량
# 흐름  종류   요소 이름
# in  건물   공기 목욕탕         21   열
#             쇼핑몰         18   열
#             수영장         16   열
#             아파트         12   열
#             학교          34   열
#             호텔           0   열
#          물  목욕탕         22   열
#             쇼핑몰         19   열
#             수영장         15   열
#             아파트         13   열
#             오피스         10   열
#             학교          36   열
#             호텔           1   열
#     에너지원 공기 공기열         28   열
#          토양 지열           8   열
# out 건물   공기 ESS 격납고     30   열
#             경기장         37   열
#             공장          40   열
#             기지국         26   열
#             냉동창고        24   열
#             목욕탕         21   열
#             쇼핑몰         18   열
#             수영장         16   열
#             아파트         12   열
#             오피스          9   열
#             테이터센터        3   열
#             학교          34   열
#             호텔           0   열
#     에너지원 공기 공기열         28   열
#          기기 발전소         33   열
#          태양 태양열          6   열
#          토양 지열           8   열

# %%
data = df.index.values.tolist()
data
# Out:
# [('in', '건물', '공기', '목욕탕'),
#  ('in', '건물', '공기', '쇼핑몰'),
#  ('in', '건물', '공기', '수영장'),
#  ('in', '건물', '공기', '아파트'),
#  ('in', '건물', '공기', '학교'),
#  ('in', '건물', '공기', '호텔'),
#  ('in', '건물', '물', '목욕탕'),
#  ('in', '건물', '물', '쇼핑몰'),
#  ('in', '건물', '물', '수영장'),
#  ('in', '건물', '물', '아파트'),
#  ('in', '건물', '물', '오피스'),
#  ('in', '건물', '물', '학교'),
#  ('in', '건물', '물', '호텔'),
#  ('in', '에너지원', '공기', '공기열'),
#  ('in', '에너지원', '토양', '지열'),
#  ('out', '건물', '공기', 'ESS 격납고'),
#  ('out', '건물', '공기', '경기장'),
#  ('out', '건물', '공기', '공장'),
#  ('out', '건물', '공기', '기지국'),
#  ('out', '건물', '공기', '냉동창고'),
#  ('out', '건물', '공기', '목욕탕'),
#  ('out', '건물', '공기', '쇼핑몰'),
#  ('out', '건물', '공기', '수영장'),
#  ('out', '건물', '공기', '아파트'),
#  ('out', '건물', '공기', '오피스'),
#  ('out', '건물', '공기', '테이터센터'),
#  ('out', '건물', '공기', '학교'),
#  ('out', '건물', '공기', '호텔'),
#  ('out', '에너지원', '공기', '공기열'),
#  ('out', '에너지원', '기기', '발전소'),
#  ('out', '에너지원', '태양', '태양열'),
#  ('out', '에너지원', '토양', '지열')]

# %%
from collections import defaultdict


def tuples_to_dict(data):
    """tuples: list[tuple]"""
    d = defaultdict(list)
    
    if not data[0]:
        return None
    
    for elems in data:
        k = elems[0]
        v = elems[1:]
        d[k].append(v)
        
    for k in d.keys():
        try:
            d[k] = dict(tuples_to_dict(d[k]))
        except:
            d[k] = {}
        
    return dict(d)


def dict_to_flare(d):
    """flare: flare format in d3 example."""
    l = []
    for k, v in d.items():
        if v:
            l.append({'name': k, 'children': dict_to_flare(v)})
        else:
            l.append({'name': k})
        
    return l


def tuples_to_flare(data):
    return dict_to_flare(tuples_to_dict(data))


json_data = tuples_to_flare(data)
print(json_data)

with open('group.json', 'w') as f:
    json.dump({'name': 'Energy', 'children': json_data}, f, indent=4)
# Out:
# [
#     {
#         'name': 'in',
#         'children': [
#             {
#                 'name': '건물',
#                 'children': [
#                     {
#                         'name': '공기',
#                         'children': [
#                             {'name': '목욕탕'},
#                             {'name': '쇼핑몰'},
#                             {'name': '수영장'},
#                             {'name': '아파트'},
#                             {'name': '학교'},
#                             {'name': '호텔'}
#                         ]
#                     },
#                     {
#                         'name': '물',
#                         'children': [
#                             {'name': '목욕탕'},
#                             {'name': '쇼핑몰'},
#                             {'name': '수영장'},
#                             {'name': '아파트'},
#                             {'name': '오피스'},
#                             {'name': '학교'},
#                             {'name': '호텔'}
#                         ]
#                     }
#                 ]
#             },
#             {
#                 'name': '에너지원',
#                 'children': [
#                     {'name': '공기', 'children': [{'name': '공기열'}]},
#                     {'name': '토양', 'children': [{'name': '지열'}]}
#                 ]
#             }
#         ]
#     },
#     {
#         'name': 'out',
#         'children': [
#             {
#                 'name': '건물',
#                 'children': [
#                     {
#                         'name': '공기',
#                         'children': [
#                             {'name': 'ESS 격납고'},
#                             {'name': '경기장'},
#                             {'name': '공장'},
#                             {'name': '기지국'},
#                             {'name': '냉동창고'},
#                             {'name': '목욕탕'},
#                             {'name': '쇼핑몰'},
#                             {'name': '수영장'},
#                             {'name': '아파트'},
#                             {'name': '오피스'},
#                             {'name': '테이터센터'},
#                             {'name': '학교'},
#                             {'name': '호텔'}
#                         ]
#                     }
#                 ]
#             },
#             {
#                 'name': '에너지원',
#                 'children': [
#                     {'name': '공기', 'children': [{'name': '공기열'}]},
#                     {'name': '기기', 'children': [{'name': '발전소'}]},
#                     {'name': '태양', 'children': [{'name': '태양열'}]},
#                     {'name': '토양', 'children': [{'name': '지열'}]}
#                 ]
#             }
#         ]
#     }
# ]

# %%
print(
    json.dumps({'name': 'root', 'children': json_data}, indent=4)
    .replace('"name"', "name")
    .replace('"children"', "children")
)
# Out:
# {
#     name: "root",
#     children: [
#         {
#             name: "in",
#             children: [
#                 {
#                     name: "\uac74\ubb3c",
#                     children: [
#                         {
#                             name: "\uacf5\uae30",
#                             children: [
#                                 {
#                                     name: "\ubaa9\uc695\ud0d5"
#                                 },
#                                 {
#                                     name: "\uc1fc\ud551\ubab0"
#                                 },
#                                 {
#                                     name: "\uc218\uc601\uc7a5"
#                                 },
#                                 {
#                                     name: "\uc544\ud30c\ud2b8"
#                                 },
#                                 {
#                                     name: "\ud559\uad50"
#                                 },
#                                 {
#                                     name: "\ud638\ud154"
#                                 }
#                             ]
#                         },
#                         {
#                             name: "\ubb3c",
#                             children: [
#                                 {
#                                     name: "\ubaa9\uc695\ud0d5"
#                                 },
#                                 {
#                                     name: "\uc1fc\ud551\ubab0"
#                                 },
#                                 {
#                                     name: "\uc218\uc601\uc7a5"
#                                 },
#                                 {
#                                     name: "\uc544\ud30c\ud2b8"
#                                 },
#                                 {
#                                     name: "\uc624\ud53c\uc2a4"
#                                 },
#                                 {
#                                     name: "\ud559\uad50"
#                                 },
#                                 {
#                                     name: "\ud638\ud154"
#                                 }
#                             ]
#                         }
#                     ]
#                 },
#                 {
#                     name: "\uc5d0\ub108\uc9c0\uc6d0",
#                     children: [
#                         {
#                             name: "\uacf5\uae30",
#                             children: [
#                                 {
#                                     name: "\uacf5\uae30\uc5f4"
#                                 }
#                             ]
#                         },
#                         {
#                             name: "\ud1a0\uc591",
#                             children: [
#                                 {
#                                     name: "\uc9c0\uc5f4"
#                                 }
#                             ]
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             name: "out",
#             children: [
#                 {
#                     name: "\uac74\ubb3c",
#                     children: [
#                         {
#                             name: "\uacf5\uae30",
#                             children: [
#                                 {
#                                     name: "ESS \uaca9\ub0a9\uace0"
#                                 },
#                                 {
#                                     name: "\uacbd\uae30\uc7a5"
#                                 },
#                                 {
#                                     name: "\uacf5\uc7a5"
#                                 },
#                                 {
#                                     name: "\uae30\uc9c0\uad6d"
#                                 },
#                                 {
#                                     name: "\ub0c9\ub3d9\ucc3d\uace0"
#                                 },
#                                 {
#                                     name: "\ubaa9\uc695\ud0d5"
#                                 },
#                                 {
#                                     name: "\uc1fc\ud551\ubab0"
#                                 },
#                                 {
#                                     name: "\uc218\uc601\uc7a5"
#                                 },
#                                 {
#                                     name: "\uc544\ud30c\ud2b8"
#                                 },
#                                 {
#                                     name: "\uc624\ud53c\uc2a4"
#                                 },
#                                 {
#                                     name: "\ud14c\uc774\ud130\uc13c\ud130"
#                                 },
#                                 {
#                                     name: "\ud559\uad50"
#                                 },
#                                 {
#                                     name: "\ud638\ud154"
#                                 }
#                             ]
#                         }
#                     ]
#                 },
#                 {
#                     name: "\uc5d0\ub108\uc9c0\uc6d0",
#                     children: [
#                         {
#                             name: "\uacf5\uae30",
#                             children: [
#                                 {
#                                     name: "\uacf5\uae30\uc5f4"
#                                 }
#                             ]
#                         },
#                         {
#                             name: "\uae30\uae30",
#                             children: [
#                                 {
#                                     name: "\ubc1c\uc804\uc18c"
#                                 }
#                             ]
#                         },
#                         {
#                             name: "\ud0dc\uc591",
#                             children: [
#                                 {
#                                     name: "\ud0dc\uc591\uc5f4"
#                                 }
#                             ]
#                         },
#                         {
#                             name: "\ud1a0\uc591",
#                             children: [
#                                 {
#                                     name: "\uc9c0\uc5f4"
#                                 }
#                             ]
#                         }
#                     ]
#                 }
#             ]
#         }
#     ]
# }

# %%
df.index
# Out:
# MultiIndex([( 'in',   '건물', '공기',     '목욕탕'),
#             ( 'in',   '건물', '공기',     '쇼핑몰'),
#             ( 'in',   '건물', '공기',     '수영장'),
#             ( 'in',   '건물', '공기',     '아파트'),
#             ( 'in',   '건물', '공기',      '학교'),
#             ( 'in',   '건물', '공기',      '호텔'),
#             ( 'in',   '건물',  '물',     '목욕탕'),
#             ( 'in',   '건물',  '물',     '쇼핑몰'),
#             ( 'in',   '건물',  '물',     '수영장'),
#             ( 'in',   '건물',  '물',     '아파트'),
#             ( 'in',   '건물',  '물',     '오피스'),
#             ( 'in',   '건물',  '물',      '학교'),
#             ( 'in',   '건물',  '물',      '호텔'),
#             ( 'in', '에너지원', '공기',     '공기열'),
#             ( 'in', '에너지원', '토양',      '지열'),
#             ('out',   '건물', '공기', 'ESS 격납고'),
#             ('out',   '건물', '공기',     '경기장'),
#             ('out',   '건물', '공기',      '공장'),
#             ('out',   '건물', '공기',     '기지국'),
#             ('out',   '건물', '공기',    '냉동창고'),
#             ('out',   '건물', '공기',     '목욕탕'),
#             ('out',   '건물', '공기',     '쇼핑몰'),
#             ('out',   '건물', '공기',     '수영장'),
#             ('out',   '건물', '공기',     '아파트'),
#             ('out',   '건물', '공기',     '오피스'),
#             ('out',   '건물', '공기',   '테이터센터'),
#             ('out',   '건물', '공기',      '학교'),
#             ('out',   '건물', '공기',      '호텔'),
#             ('out', '에너지원', '공기',     '공기열'),
#             ('out', '에너지원', '기기',     '발전소'),
#             ('out', '에너지원', '태양',     '태양열'),
#             ('out', '에너지원', '토양',      '지열')],
#            names=['흐름', '종류', '요소', '이름'])

# %%
df = csv_df[csv_df['이름'] != '지열']
df = df.reset_index().set_index(['대상량', '이름', '흐름']).sort_index()
df = df.loc['열']
df
# Out:
#              index    종류  요소
# 이름      흐름
# ESS 격납고 out     30    건물  공기
# 경기장     out     37    건물  공기
# 공기열     in      28  에너지원  공기
#         out     28  에너지원  공기
# 공장      out     40    건물  공기
# 기지국     out     26    건물  공기
# 냉동창고    out     24    건물  공기
# 목욕탕     in      22    건물   물
#         in      21    건물  공기
#         out     21    건물  공기
# 발전소     out     33  에너지원  기기
# 쇼핑몰     in      19    건물   물
#         in      18    건물  공기
#         out     18    건물  공기
# 수영장     in      15    건물   물
#         in      16    건물  공기
#         out     16    건물  공기
# 아파트     in      13    건물   물
#         in      12    건물  공기
#         out     12    건물  공기
# 오피스     in      10    건물   물
#         out      9    건물  공기
# 태양열     out      6  에너지원  태양
# 테이터센터   out      3    건물  공기
# 학교      in      36    건물   물
#         in      34    건물  공기
#         out     34    건물  공기
# 호텔      in       1    건물   물
#         in       0    건물  공기
#         out      0    건물  공기

# %%
data = df.index.values.tolist()
data = sorted(set(data))
data
# Out:
# [('ESS 격납고', 'out'),
#  ('경기장', 'out'),
#  ('공기열', 'in'),
#  ('공기열', 'out'),
#  ('공장', 'out'),
#  ('기지국', 'out'),
#  ('냉동창고', 'out'),
#  ('목욕탕', 'in'),
#  ('목욕탕', 'out'),
#  ('발전소', 'out'),
#  ('쇼핑몰', 'in'),
#  ('쇼핑몰', 'out'),
#  ('수영장', 'in'),
#  ('수영장', 'out'),
#  ('아파트', 'in'),
#  ('아파트', 'out'),
#  ('오피스', 'in'),
#  ('오피스', 'out'),
#  ('태양열', 'out'),
#  ('테이터센터', 'out'),
#  ('학교', 'in'),
#  ('학교', 'out'),
#  ('호텔', 'in'),
#  ('호텔', 'out')]

# %%
import random

l = []
for i, (name, direction) in enumerate(data):
    if direction == 'out':
        imports = [
            f'energy.{n}.{d}' for j, (n, d) in enumerate(data)
            if direction != d and i != j and random.random() < 0.2 and n != name
        ]
    else:
        imports = []
        
    l.append({'name': f'energy.{name}.{direction}', 'imports': imports, 'size': np.abs(np.random.normal(3, 3))+3})

# %%
l
# Out:
# [{'name': 'energy.ESS 격납고.out',
#   'imports': ['energy.공기열.in', 'energy.오피스.in', 'energy.학교.in'],
#   'size': 6.558135936199125},
#  {'name': 'energy.경기장.out',
#   'imports': ['energy.공기열.in', 'energy.쇼핑몰.in'],
#   'size': 4.081984424657464},
#  {'name': 'energy.공기열.in', 'imports': [], 'size': 5.412806624750124},
#  {'name': 'energy.공기열.out',
#   'imports': ['energy.아파트.in', 'energy.학교.in'],
#   'size': 3.1548437302171566},
#  {'name': 'energy.공장.out',
#   'imports': ['energy.공기열.in', 'energy.호텔.in'],
#   'size': 5.205399491144495},
#  {'name': 'energy.기지국.out', 'imports': [], 'size': 9.04385695411499},
#  {'name': 'energy.냉동창고.out', 'imports': [], 'size': 4.057519439023441},
#  {'name': 'energy.목욕탕.in', 'imports': [], 'size': 9.944621223801036},
#  {'name': 'energy.목욕탕.out',
#   'imports': ['energy.쇼핑몰.in',
#    'energy.오피스.in',
#    'energy.학교.in',
#    'energy.호텔.in'],
#   'size': 5.18762256141586},
#  {'name': 'energy.발전소.out',
#   'imports': ['energy.공기열.in', 'energy.오피스.in', 'energy.호텔.in'],
#   'size': 3.922132598474935},
#  {'name': 'energy.쇼핑몰.in', 'imports': [], 'size': 5.01382995138554},
#  {'name': 'energy.쇼핑몰.out', 'imports': [], 'size': 5.068618381461464},
#  {'name': 'energy.수영장.in', 'imports': [], 'size': 3.074355231645561},
#  {'name': 'energy.수영장.out',
#   'imports': ['energy.아파트.in'],
#   'size': 9.166777603234209},
#  {'name': 'energy.아파트.in', 'imports': [], 'size': 5.310046457870894},
#  {'name': 'energy.아파트.out',
#   'imports': ['energy.수영장.in'],
#   'size': 8.817067001811052},
#  {'name': 'energy.오피스.in', 'imports': [], 'size': 10.512973536043397},
#  {'name': 'energy.오피스.out',
#   'imports': ['energy.쇼핑몰.in'],
#   'size': 3.89263254505693},
#  {'name': 'energy.태양열.out',
#   'imports': ['energy.학교.in'],
#   'size': 5.156836078911857},
#  {'name': 'energy.테이터센터.out',
#   'imports': ['energy.쇼핑몰.in', 'energy.수영장.in'],
#   'size': 7.226873082833833},
#  {'name': 'energy.학교.in', 'imports': [], 'size': 7.606201935859213},
#  {'name': 'energy.학교.out',
#   'imports': ['energy.쇼핑몰.in'],
#   'size': 3.098190554250568},
#  {'name': 'energy.호텔.in', 'imports': [], 'size': 9.119597605049215},
#  {'name': 'energy.호텔.out',
#   'imports': ['energy.쇼핑몰.in', 'energy.수영장.in'],
#   'size': 9.239616474838742}]

# %%
with open('link.json', 'w') as f:
    json.dump(l, f, indent=4)
